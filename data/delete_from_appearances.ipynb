# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("appearances_cleaned.csv")

# %%
data.head()
# Out:
#     appearance_id  game_id  player_id  player_club_id  player_current_club_id  \
# 0  2469214_124866  2469214     124866             202                    1283
# 1  2469214_124888  2469214     124888             202                     202
# 2   2469214_12765  2469214      12765             370                     370
# 3   2469214_12804  2469214      12804             370                     370
# 4   2469214_12817  2469214      12817             370                     465
#
#          date       player_name competition_id  yellow_cards  red_cards  \
# 0  2014-07-17    Lorenzo Burnet            ELQ             0          0
# 1  2014-07-17   Johan Kappelhof            ELQ             0          0
# 2  2014-07-17  Russell Anderson            ELQ             0          0
# 3  2014-07-17      Barry Robson            ELQ             0          0
# 4  2014-07-17   Jamie Langfield            ELQ             0          0
#
#    goals  assists  minutes_played
# ...

# %%
### randomly select 100000 rows

data = data.sample(n=100000, random_state=1)

# %%
# write to csv
data.to_csv("appearances_cleaned_sample.csv", index=False)
